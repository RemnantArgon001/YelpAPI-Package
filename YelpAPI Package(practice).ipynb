# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
with open('/Users/tanma/.secret/yelp_api.json') as f:   #use your path here!
    login = json.load(f)
# Instantiate YelpAPI Variable
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)

# %%
help(yelp_api.search_query)
# Out:
# Help on method search_query in module yelpapi.yelpapi:
#
# search_query(**kwargs) method of yelpapi.yelpapi.YelpAPI instance
#     Query the Yelp Search API.
#
#     documentation: https://www.yelp.com/developers/documentation/v3/business_search
#
#     required parameters:
#         * one of either:
#             * location - text specifying a location to search for
#             * latitude and longitude

# %%
# use our yelp_api variable's search_query method to perform our API call
search_results = yelp_api.search_query(location='Austin, TX,78701',
                                       term='Ramen')
print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
search_results['total']
# Out:
# 77

# %%
biz = pd.DataFrame(search_results['businesses'])
biz.head()
# Out:
#                        id                     alias             name  \
# 0  uwFa-pTQL1Rv4nULoIraNw   ramen-tatsu-ya-austin-2   Ramen Tatsu-Ya
# 1  7ZU9DwctpN_tkC7EOd3C-Q   ramen-tatsu-ya-austin-6   Ramen Tatsu-Ya
# 2  yqL1P6wcSZYQAgpO3TfhBQ  kemuri-tatsu-ya-austin-2  Kemuri Tatsu-ya
# 3  HKi7fd2bTzZfVB_Dz9vGng        lucky-robot-austin      Lucky Robot
# 4  nXtn29mTWlYeHxvHSz4dfA           koriente-austin         Koriente
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/rNrHEy...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/5QE3yx...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/YloCTt...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/-8j6xG...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/JAENxB...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/ramen-tatsu-ya-austin...          1879
# ...

# %%
len(search_results['businesses'])
# Out:
# 20

# %%
search_results = yelp_api.search_query(location='Austin, TX,78701',
                                       term='Ramen',
                                       offset = 20)

# %%
biz20 = pd.DataFrame(search_results['businesses'])
biz20.head(2)
# Out:
#                        id               alias        name  \
# 0  0lgGW93HYeVqrTTx9d3gUA    chilantro-austin  Chi'Lantro
# 1  2ZVSDvbFK2DNoZb9x7NlfQ  chilantro-austin-7  Chi'Lantro
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/EgkriI...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/cbQcpk...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/chilantro-austin?adju...           724
# 1  https://www.yelp.com/biz/chilantro-austin-7?ad...           693
#
#                                           categories  rating  \
# 0  [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.0
# 1  [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.0
#
#                                         coordinates        transactions price  \
# 0    {'latitude': 30.27007, 'longitude': -97.74187}          [delivery]     $
# ...

# %%
businesses = pd.concat([biz, biz20],
                      ignore_index=True)
display(businesses.head(3), businesses.tail(3))
# Out:
#                        id                     alias             name  \
# 0  uwFa-pTQL1Rv4nULoIraNw   ramen-tatsu-ya-austin-2   Ramen Tatsu-Ya
# 1  7ZU9DwctpN_tkC7EOd3C-Q   ramen-tatsu-ya-austin-6   Ramen Tatsu-Ya
# 2  yqL1P6wcSZYQAgpO3TfhBQ  kemuri-tatsu-ya-austin-2  Kemuri Tatsu-ya
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/rNrHEy...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/5QE3yx...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/YloCTt...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/ramen-tatsu-ya-austin...          1879
# 1  https://www.yelp.com/biz/ramen-tatsu-ya-austin...           585
# 2  https://www.yelp.com/biz/kemuri-tatsu-ya-austi...           784
#
#                                           categories  rating  \
# 0             [{'alias': 'ramen', 'title': 'Ramen'}]     4.0
# ...

# %%
search_results = yelp_api.search_query(location='Austin, TX,78701',
                                       term='Ramen',
                                       offset = 39)

# %%
biz39 = pd.DataFrame(search_results['businesses'])
biz39.head(2)
# Out:
#                        id                                 alias  \
# 0  FZ3M3K7yIvIj770TE4JpKw                   omas-kitchen-austin
# 1  yDH9wE7IPEA_hm-B5c_24w  raku-sushi-and-asian-bistro-austin-2
#
#                           name  \
# 0                Oma's Kitchen
# 1  Raku Sushi and Asian Bistro
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/n7jMsR...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/0VwEgm...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/omas-kitchen-austin?a...            99
# 1  https://www.yelp.com/biz/raku-sushi-and-asian-...           243
#
#                                           categories  rating  \
# 0           [{'alias': 'korean', 'title': 'Korean'}]     4.0
# 1  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     3.5
#
#                                          coordinates        transactions  \
# ...

# %%
businesses = pd.concat([biz, biz20, biz39],
                      ignore_index=True)
display(businesses.head(3), businesses.tail(3))
# Out:
#                        id                     alias             name  \
# 0  uwFa-pTQL1Rv4nULoIraNw   ramen-tatsu-ya-austin-2   Ramen Tatsu-Ya
# 1  7ZU9DwctpN_tkC7EOd3C-Q   ramen-tatsu-ya-austin-6   Ramen Tatsu-Ya
# 2  yqL1P6wcSZYQAgpO3TfhBQ  kemuri-tatsu-ya-austin-2  Kemuri Tatsu-ya
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/rNrHEy...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/5QE3yx...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/YloCTt...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/ramen-tatsu-ya-austin...          1879
# 1  https://www.yelp.com/biz/ramen-tatsu-ya-austin...           585
# 2  https://www.yelp.com/biz/kemuri-tatsu-ya-austi...           784
#
#                                           categories  rating  \
# 0             [{'alias': 'ramen', 'title': 'Ramen'}]     4.0
# ...

# %%
search_results = yelp_api.search_query(location='Austin, TX,78701',
                                       term='Ramen',
                                       offset = 59)

# %%
biz59 = pd.DataFrame(search_results['businesses'])
biz59.head(2)
# Out:
#                        id                       alias                 name  \
# 0  uK3hclf6oje7rRAbUhPCLg          sushi-junai-austin          Sushi Junai
# 1  bZiIIUcpgxh8mpKMDhdqbA  hopdoddy-burger-bar-austin  Hopdoddy Burger Bar
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/ntw8LB...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/isEobb...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/sushi-junai-austin?ad...           554
# 1  https://www.yelp.com/biz/hopdoddy-burger-bar-a...          4898
#
#                                           categories  rating  \
# 0  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     3.5
# 1  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
#
#                                         coordinates        transactions price  \
# ...

# %%
businesses = pd.concat([biz, biz20, biz39,biz59],
                      ignore_index=True)
display(businesses.head(3), businesses.tail(3))
# Out:
#                        id                     alias             name  \
# 0  uwFa-pTQL1Rv4nULoIraNw   ramen-tatsu-ya-austin-2   Ramen Tatsu-Ya
# 1  7ZU9DwctpN_tkC7EOd3C-Q   ramen-tatsu-ya-austin-6   Ramen Tatsu-Ya
# 2  yqL1P6wcSZYQAgpO3TfhBQ  kemuri-tatsu-ya-austin-2  Kemuri Tatsu-ya
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/rNrHEy...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/5QE3yx...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/YloCTt...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/ramen-tatsu-ya-austin...          1879
# 1  https://www.yelp.com/biz/ramen-tatsu-ya-austin...           585
# 2  https://www.yelp.com/biz/kemuri-tatsu-ya-austi...           784
#
#                                           categories  rating  \
# 0             [{'alias': 'ramen', 'title': 'Ramen'}]     4.0
# ...
